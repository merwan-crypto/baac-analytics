# %%
# %pip install lxml streamlit pyngrok
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lxml in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (6.0.2)
# Requirement already satisfied: streamlit in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (1.51.0)
# Requirement already satisfied: pyngrok in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (7.5.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (6.2.1)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (8.3.0)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (2.3.4)
# Requirement already satisfied: packaging<26,>=20 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (6.33.0)
# Requirement already satisfied: pyarrow<22,>=7.0 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: jinja2 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.10.2)
# Requirement already satisfied: colorama in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from requests<3,>=2.27->streamlit) (2025.10.5)
# Requirement already satisfied: PyYAML>=5.1 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from pyngrok) (6.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.28.0)
# Requirement already satisfied: six>=1.5 in C:\Users\merwa\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st

# %%
TOKEN_NGROK = "35hHUkG2OkYWjgKIU2nwzfkUa4V_4DxvtLBKWmDFM5eVmdErv"

# %%
from pyngrok import ngrok
import os

ngrok.set_auth_token(TOKEN_NGROK)

# Définir le port pour Streamlit
port = 8501

# Configurer et démarrer ngrok
public_url = ngrok.connect(port).public_url
print(f"Streamlit sera accessible publiquement en cliquant sur ce lien : {public_url}")
# Out:
# Streamlit sera accessible publiquement en cliquant sur ce lien : https://adjudicative-vella-unsocketed.ngrok-free.dev
# t=2026-03-12T17:18:18+0100 lvl=warn msg="failed to open private leg" id=dcc70dc3c66e privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:18:18+0100 lvl=warn msg="failed to open private leg" id=90d4069111a1 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:18:18+0100 lvl=warn msg="failed to open private leg" id=e8fb8bb31854 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:18:18+0100 lvl=warn msg="failed to open private leg" id=95ff7768c068 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:18:19+0100 lvl=warn msg="failed to open private leg" id=5026b8ebe001 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:18:19+0100 lvl=warn msg="failed to open private leg" id=e6a9da7231be privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:18:20+0100 lvl=warn msg="failed to open private leg" id=68128bcc3f97 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:18:20+0100 lvl=warn msg="failed to open private leg" id=f2b7a1efd7f1 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:18:21+0100 lvl=warn msg="failed to open private leg" id=b4a68943ae72 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:18:21+0100 lvl=warn msg="failed to open private leg" id=5e46823550f4 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:02+0100 lvl=warn msg="failed to open private leg" id=075f3863206d privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:02+0100 lvl=warn msg="failed to open private leg" id=3561c54ca05a privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:03+0100 lvl=warn msg="failed to open private leg" id=f8c0c32e9dc6 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:03+0100 lvl=warn msg="failed to open private leg" id=44e8113bc26f privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:04+0100 lvl=warn msg="failed to open private leg" id=b24648b72998 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:04+0100 lvl=warn msg="failed to open private leg" id=acdb9e82b94a privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:05+0100 lvl=warn msg="failed to open private leg" id=8a01d6ca4012 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:05+0100 lvl=warn msg="failed to open private leg" id=643bd07095a2 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:06+0100 lvl=warn msg="failed to open private leg" id=17be0f86fad3 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:06+0100 lvl=warn msg="failed to open private leg" id=d40f318ee76e privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:08+0100 lvl=warn msg="failed to open private leg" id=a5fb78bddee6 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:08+0100 lvl=warn msg="failed to open private leg" id=7b26a4f071f0 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:11+0100 lvl=warn msg="failed to open private leg" id=18f9e1ba2496 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:11+0100 lvl=warn msg="failed to open private leg" id=1ebe210bfed6 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:13+0100 lvl=warn msg="failed to open private leg" id=44fb500bd408 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:14+0100 lvl=warn msg="failed to open private leg" id=e874bc2a9f91 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:22+0100 lvl=warn msg="failed to open private leg" id=71d9a95509a5 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."
# t=2026-03-12T17:19:54+0100 lvl=warn msg="failed to open private leg" id=69a15327f215 privaddr=localhost:8501 err="dial tcp [::1]:8501: connectex: No connection could be made because the target machine actively refused it."

# %%
print("Rappel : Cliquez ici pour accéder à l'application Streamlit :", public_url)
print("P.S : Appuyez sur l'icône 'Stop' plus haut pour arrêter l'exécution de cette cellule qui ne s'arrêtera pas tant que vous ne lui aurez pas ordonné.")
os.system(f"streamlit run main.py --server.port {port}")
# Out:
# Rappel : Cliquez ici pour accéder à l'application Streamlit : https://adjudicative-vella-unsocketed.ngrok-free.dev
# P.S : Appuyez sur l'icône 'Stop' plus haut pour arrêter l'exécution de cette cellule qui ne s'arrêtera pas tant que vous ne lui aurez pas ordonné.
# 1
